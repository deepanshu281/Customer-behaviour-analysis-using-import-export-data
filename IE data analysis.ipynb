# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ydata_profiling import ProfileReport

# %%
#Load Data
file_data = r'C:/Users/deepa/Desktop/Import data/import_data.csv'
df = pd.read_csv(file_data, encoding='utf-8-sig')
df.head()
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20752\424163941.py:3: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_data, encoding='utf-8-sig')
#          Date     HS Code                                Product Description  \
# 0  01-04-2022  29052220.0  GERANIOL EXTRA/PO:4970353135/00010ACYCLIC TERP...
# 1  01-04-2022  29143990.0  PHANTOLIDE ORGANIC CHEMICAL FOR  MANUFACTURING...
# 2  01-04-2022  29143990.0    2,4 DICHLORO ACETOPHENONE INTERMEDIATE CHEMICAL
# 3  01-04-2022  29143990.0  B-GLUCURONIC ACID-1-3N-ACETYL-B-GALACTOSAMINE-...
# 4  01-04-2022  29061990.0  FENCHYL ALCOHOL END USE BY BUYERS OF OUR FINIS...
#
#         Importer Name                                      Importer Add1  \
# 0  BASF INDIA LIMITED  THE CAPITAL, A WING, 1204-C,,12TH FLOOR, PLOT ...
# 1  GIVAUDAN I PVT LTD  PLOT NO.26,2ND CROSS,JIGANI,INDUST RIAL AREA,J...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489290 entries, 0 to 489289
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       369255 non-null  object
#  1   HS Code                    369255 non-null  float64
#  2   Product Description        369254 non-null  object
#  3   Importer Name              369232 non-null  object
#  4   Importer Add1              344668 non-null  object
#  5   Importer City              324860 non-null  object
#  6   Importer Pincode           364998 non-null  float64
#  7   Importer State             328000 non-null  object
#  8   Importer Phone             356299 non-null  object
#  9   Importer E-mail            316009 non-null  object
#  10  Contact Person             327338 non-null  object
#  11  Exporter Name              368718 non-null  object
#  12  QTY                        369255 non-null  object
# ...

# %%
# Cleaning Data

# Specify the columns to keep
columns_to_keep = ['Date', 'HS Code', 'Product Description', 'Importer Name',
                   'Importer State', 'Exporter Name', 'Standard Qty', 
                   'Standard Unit', 'Port of Destination', 'Shipment Mode', 
                   'Country of Origin', 'Port Of Origin']

# Filter out required products with exact string matching
products_to_filter = ['ORTHOXYLENE', 'PARAXYLENE', 'Vinyl Acetate Monomer', 
                      'Styrene Monomer', 'Butyl acetate']

# Create a filtered DataFrame based on exact matches
filtered_df = df[df['Product Description'].isin(products_to_filter)]

# Keep only the necessary columns
filtered_df_cleaned = filtered_df[columns_to_keep]

# Drop rows with missing values (optional)
filtered_df_cleaned = filtered_df_cleaned.dropna()
filtered_df_cleaned.head()
# Out:
#             Date     HS Code Product Description  \
# 2945  04-04-2022  29153300.0       Butyl acetate
# 3166  04-04-2022  29153300.0       Butyl acetate
# 3830  04-04-2022  29153300.0       Butyl acetate
# 7982  07-04-2022  29153300.0       Butyl acetate
# 9696  08-04-2022  29153300.0       Butyl acetate
#
#                              Importer Name Importer State  \
# 2945            MERCK LIFE SCIENCE PVT LTD    MAHARASHTRA
# 3166            MERCK LIFE SCIENCE PVT LTD    MAHARASHTRA
# 3830                           C J SHAH CO    MAHARASHTRA
# 7982  TAKASAGO INTERNATIONAL INDIA PVT LTD     TAMIL NADU
# 9696              JUPITER DYE CHEM PVT LTD    MAHARASHTRA
#
#               Exporter Name Standard Qty Standard Unit Port of Destination  \
# 2945             MERCK KGAA          2.2           KGS          Bombay Air
# 3166             MERCK KGAA          8.8           KGS          Bombay Air
# 3830       CELANESE PTE LTD  2,00,000.00           KGS                JNPT
# ...

# %%
small_butyl_acetate_importers = filtered_df_cleaned[
    (filtered_df_cleaned['Product Description'] == 'Styrene Monomer')
]
small_butyl_acetate_importers.head()
# Out:
# Empty DataFrame
# Columns: [Date, HS Code, Product Description, Importer Name, Importer State, Exporter Name, Standard Qty, Standard Unit, Port of Destination, Shipment Mode, Country of Origin, Port Of Origin]
# Index: []
